# %%
import pandas as pd

# 1) đọc kaggle news dataset
kaggle_df = pd.read_csv("kaggle_news_preprocess.csv")

# 1) đọc collected news dataset
collected_df = pd.read_csv("collected_news_preprocess.csv")

# %%
print(kaggle_df.shape)
kaggle_df.head()
# Out:
# (11619, 5)
#                                              content  \
# 0  “Thương hiệu dẫn đầu Việt Nam – Vietnam Leadin...
# 1  Tính đến hết tháng 11/2019, vốn hóa  thị trườn...
# 2  Vàng miếng SJC tại Vàng bạc Đá quý Sài Gòn tiế...
# 3  Lệnh vào nhấp nháy liên tục trên bảng điện tại...
# 4  Chứng khoán Trung Quốc đại lục mở phiên khá ảm...
#
#                                        content_clean       date  \
# 0  Thương hiệu dẫn đầu Việt Nam Vietnam Leading B... 2019-12-16
# 1  Tính đến hết tháng 11/2019, vốn hóa thị trường... 2019-12-16
# 2  Vàng miếng SJC tại Vàng bạc Đá quý Sài Gòn tiế... 2019-12-17
# 3  Lệnh vào nhấp nháy liên tục trên bảng điện tại... 2019-12-20
# 4  Chứng khoán Trung Quốc đại lục mở phiên khá ảm... 2019-12-23
#
#                                                title  \
# 0  BVSC nhận “Top 10 thương hiệu dẫn đầu Việt Nam...
# 1  Thị trường chứng khoán: Thanh khoản muốn tăng,...
# 2  Giá vàng 14/12 tiếp tục tăng, đồng bảng Anh lậ...
# 3  Thị trường chứng khoán: Trăn trở khi penny dậy...
# 4  Chứng khoán Trung Quốc vẫn yên ắng sau tin cắt...
#
#                                                  url
# 0  https://baodautu.vn/bvsc-nhan-top-10-thuong-hi...
# 1  https://baodautu.vn/thi-truong-chung-khoan-tha...
# 2  https://baodautu.vn/gia-vang-1412-tiep-tuc-tan...
# 3  https://baodautu.vn/thi-truong-chung-khoan-tra...
# 4  https://baodautu.vn/chung-khoan-trung-quoc-van...

# %%
print(collected_df.shape)
collected_df.head()
# Out:
# (2120, 5)
#                                              content  \
# 0  Một thương vụ bán vốn giữa ngân hàng nội và đố...
# 1                   ACB: 9.5% với thời hạn 12 tháng.
# 2  Trong tuần đầu tiên của năm 2020, tỷ giá trung...
# 3  Trong vụ án “Tranh chấp Hợp đồng tín dụng” giữ...
# 4  Trong tháng 1, mức lãi suất cao nhất tại ngân ...
#
#                                        content_clean       date  \
# 0  Một thương vụ bán vốn giữa ngân hàng nội và đố... 2020-01-01
# 1                   ACB: 9.5% với thời hạn 12 tháng. 2020-01-02
# 2  Trong tuần đầu tiên của năm 2020, tỷ giá trung... 2020-01-03
# 3  Trong vụ án Tranh chấp Hợp đồng tín dụng giữa ... 2020-01-04
# 4  Trong tháng 1, mức lãi suất cao nhất tại ngân ... 2020-01-05
#
#                                                title  \
# 0  Ngân hàng khởi động năm mới 2020: Sôi động lên...
# 1  Bảng lãi suất cho vay ưu đãi mua nhà tháng 01/...
# 2              Đầu năm 2020, tỷ giá USD/VND hạ nhiệt
# 3  TP Hà Nội: Chi cục THADS huyện Thanh Oai có ...
# 4       Lãi suất ngân hàng ACB mới nhất tháng 1/2020
#
#                                                  url
# 0  https://baodautu.vn/ngan-hang-khoi-dong-nam-mo...
# 1  https://www.facebook.com/groups/reviewbatdongs...
# 2  https://vietstock.vn/2020/01/dau-nam-2020-ty-g...
# 3  https://ngaymoionline.com.vn/tp-ha-no-i-chi-cu...
# 4  https://vietnambiz.vn/lai-suat-ngan-hang-acb-m...

# %%
kaggle_df = kaggle_df.drop(columns=["Unnamed: 0", "category"])

# %%
collected_df = collected_df.drop(columns=["tok_phobert", "tok_vn_embed", "tok_vn_doc"])

# %%
kaggle_df["date"] = pd.to_datetime(kaggle_df["date"], errors="coerce")

# %%
collected_df["date"] = pd.to_datetime(collected_df["date"], errors="coerce")

# %%
kaggle_df.head()
# Out:
#         date                                                url  \
# 0 2019-12-16  https://baodautu.vn/bvsc-nhan-top-10-thuong-hi...
# 1 2019-12-16  https://baodautu.vn/thi-truong-chung-khoan-tha...
# 2 2019-12-17  https://baodautu.vn/gia-vang-1412-tiep-tuc-tan...
# 3 2019-12-20  https://baodautu.vn/thi-truong-chung-khoan-tra...
# 4 2019-12-23  https://baodautu.vn/chung-khoan-trung-quoc-van...
#
#                                                title  \
# 0  BVSC nhận “Top 10 thương hiệu dẫn đầu Việt Nam...
# 1  Thị trường chứng khoán: Thanh khoản muốn tăng,...
# 2  Giá vàng 14/12 tiếp tục tăng, đồng bảng Anh lậ...
# 3  Thị trường chứng khoán: Trăn trở khi penny dậy...
# 4  Chứng khoán Trung Quốc vẫn yên ắng sau tin cắt...
#
#                                              content  \
# 0  “Thương hiệu dẫn đầu Việt Nam – Vietnam Leadin...
# 1  Tính đến hết tháng 11/2019, vốn hóa  thị trườn...
# 2  Vàng miếng SJC tại Vàng bạc Đá quý Sài Gòn tiế...
# 3  Lệnh vào nhấp nháy liên tục trên bảng điện tại...
# 4  Chứng khoán Trung Quốc đại lục mở phiên khá ảm...
#
#                                        content_clean
# 0  Thương hiệu dẫn đầu Việt Nam Vietnam Leading B...
# 1  Tính đến hết tháng 11/2019, vốn hóa thị trường...
# 2  Vàng miếng SJC tại Vàng bạc Đá quý Sài Gòn tiế...
# 3  Lệnh vào nhấp nháy liên tục trên bảng điện tại...
# 4  Chứng khoán Trung Quốc đại lục mở phiên khá ảm...

# %%
collected_df.head()
# Out:
#         date                                                url  \
# 0 2020-01-01  https://baodautu.vn/ngan-hang-khoi-dong-nam-mo...
# 1 2020-01-02  https://www.facebook.com/groups/reviewbatdongs...
# 2 2020-01-03  https://vietstock.vn/2020/01/dau-nam-2020-ty-g...
# 3 2020-01-04  https://ngaymoionline.com.vn/tp-ha-no-i-chi-cu...
# 4 2020-01-05  https://vietnambiz.vn/lai-suat-ngan-hang-acb-m...
#
#                                                title  \
# 0  Ngân hàng khởi động năm mới 2020: Sôi động lên...
# 1  Bảng lãi suất cho vay ưu đãi mua nhà tháng 01/...
# 2              Đầu năm 2020, tỷ giá USD/VND hạ nhiệt
# 3  TP Hà Nội: Chi cục THADS huyện Thanh Oai có ...
# 4       Lãi suất ngân hàng ACB mới nhất tháng 1/2020
#
#                                              content  \
# 0  Một thương vụ bán vốn giữa ngân hàng nội và đố...
# 1                   ACB: 9.5% với thời hạn 12 tháng.
# 2  Trong tuần đầu tiên của năm 2020, tỷ giá trung...
# 3  Trong vụ án “Tranh chấp Hợp đồng tín dụng” giữ...
# 4  Trong tháng 1, mức lãi suất cao nhất tại ngân ...
#
#                                        content_clean
# 0  Một thương vụ bán vốn giữa ngân hàng nội và đố...
# 1                   ACB: 9.5% với thời hạn 12 tháng.
# 2  Trong tuần đầu tiên của năm 2020, tỷ giá trung...
# 3  Trong vụ án Tranh chấp Hợp đồng tín dụng giữa ...
# 4  Trong tháng 1, mức lãi suất cao nhất tại ngân ...

# %%
# 4) Chỉ giữ các cột chung (để concat không lệch schema)
common_cols = sorted(set(kaggle_df.columns).intersection(collected_df.columns))
kaggle_df = kaggle_df[common_cols]
collected_df = collected_df[common_cols]

# 5) Gộp
combined_df = pd.concat([kaggle_df, collected_df], ignore_index=True)

# 6) Sort theo date
combined_df = combined_df.sort_values("date").reset_index(drop=True)

print(combined_df.shape)
combined_df.head()
# Out:
# (13739, 5)
#                                              content  \
# 0  “Thương hiệu dẫn đầu Việt Nam – Vietnam Leadin...
# 1  Tính đến hết tháng 11/2019, vốn hóa  thị trườn...
# 2  Vàng miếng SJC tại Vàng bạc Đá quý Sài Gòn tiế...
# 3  Lệnh vào nhấp nháy liên tục trên bảng điện tại...
# 4  Chứng khoán Trung Quốc đại lục mở phiên khá ảm...
#
#                                        content_clean       date  \
# 0  Thương hiệu dẫn đầu Việt Nam Vietnam Leading B... 2019-12-16
# 1  Tính đến hết tháng 11/2019, vốn hóa thị trường... 2019-12-16
# 2  Vàng miếng SJC tại Vàng bạc Đá quý Sài Gòn tiế... 2019-12-17
# 3  Lệnh vào nhấp nháy liên tục trên bảng điện tại... 2019-12-20
# 4  Chứng khoán Trung Quốc đại lục mở phiên khá ảm... 2019-12-23
#
#                                                title  \
# 0  BVSC nhận “Top 10 thương hiệu dẫn đầu Việt Nam...
# 1  Thị trường chứng khoán: Thanh khoản muốn tăng,...
# 2  Giá vàng 14/12 tiếp tục tăng, đồng bảng Anh lậ...
# 3  Thị trường chứng khoán: Trăn trở khi penny dậy...
# 4  Chứng khoán Trung Quốc vẫn yên ắng sau tin cắt...
#
#                                                  url
# 0  https://baodautu.vn/bvsc-nhan-top-10-thuong-hi...
# 1  https://baodautu.vn/thi-truong-chung-khoan-tha...
# 2  https://baodautu.vn/gia-vang-1412-tiep-tuc-tan...
# 3  https://baodautu.vn/thi-truong-chung-khoan-tra...
# 4  https://baodautu.vn/chung-khoan-trung-quoc-van...

# %%
combined_df = combined_df.set_index("date").sort_index()

# kiểm tra trùng index(date)
print("Rows with duplicated date index:", combined_df.index.duplicated(keep=False).sum())
# Out:
# Rows with duplicated date index: 13349

# %%
combined_df
# Out:
#                                                       content  \
# date
# 2019-12-16  “Thương hiệu dẫn đầu Việt Nam – Vietnam Leadin...
# 2019-12-16  Tính đến hết tháng 11/2019, vốn hóa  thị trườn...
# 2019-12-17  Vàng miếng SJC tại Vàng bạc Đá quý Sài Gòn tiế...


# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 13739 entries, 2019-12-16 to 2025-10-20
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   content        13739 non-null  object
#  1   content_clean  13739 non-null  object
#  2   title          13735 non-null  object
#  3   url            13739 non-null  object
# dtypes: object(4)
# memory usage: 1.0+ MB

# %%
missing_title = combined_df[combined_df["title"].isna()]
print(missing_title.shape)
missing_title
# Out:
# (4, 4)
#                                                       content  \
# date
# 2020-10-12  Theo SSI Research, lợi nhuận trước thuế trong ...
# 2022-07-10  Giá USD chợ đen tăng vọt mốc 24.000 đồng, giá ...
# 2023-08-27  Cập nhật giá vàng hôm nay 27.8: Trong cuộc khả...
# 2024-08-24  Giá vàng thế giới hôm nay (24/8) tăng mạnh lên...
#
#                                                 content_clean title  \
# date
# 2020-10-12  Theo SSI Research, lợi nhuận trước thuế trong ...   NaN
# 2022-07-10  Giá USD chợ đen tăng vọt mốc 24.000 đồng, giá ...   NaN
# 2023-08-27  Cập nhật giá vàng hôm nay 27.8: Trong cuộc khả...   NaN
# 2024-08-24  Giá vàng thế giới hôm nay (24/8) tăng mạnh lên...   NaN
#
#                                                           url
# date
# 2020-10-12  https://vietnambiz.vn/loi-nhuan-nhieu-ngan-han...
# 2022-07-10  https://laodong.vn/tien-te-dau-tu/gia-usd-cho-...
# 2023-08-27  https://laodong.vn/infographic/cap-nhat-gia-va...
# 2024-08-24  https://nhandan.vn/gia-vang-ngay-248-vang-nhan...

# %%
titles = [
    "Lợi nhuận nhiều ngân hàng được dự báo tăng mạnh trong quí III/2020",
    "Giá USD chợ đen phá đỉnh 24.000 đồng, giá vàng chưa thể ngóc đầu",
    "Cập nhật giá vàng hôm nay trong nước và thế giới 27.8",
    "Giá vàng ngày 24/8: Vàng nhẫn neo ở mức đỉnh"
]

combined_df.loc[combined_df["title"].isna(), "title"] = titles

# %%
missing_title = combined_df[combined_df["title"].isna()]
print(missing_title.shape)
missing_title
# Out:
# (0, 4)
# Empty DataFrame
# Columns: [content, content_clean, title, url]
# Index: []

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 13739 entries, 2019-12-16 to 2025-10-20
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   content        13739 non-null  object
#  1   content_clean  13739 non-null  object
#  2   title          13739 non-null  object
#  3   url            13739 non-null  object
# dtypes: object(4)
# memory usage: 1.0+ MB

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.12/dist-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.12/dist-packages (from wordcloud) (2.0.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from wordcloud) (11.3.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from wordcloud) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Giả sử cột đã là content_clean
text = " ".join(combined_df["content_clean"].astype(str).tolist())
len(text)

wc = WordCloud(
    width=1200,
    height=600,
    background_color="white"   # màu nền, còn màu chữ để mặc định
).generate(text)

plt.figure(figsize=(14, 7))
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
mask_2024 = combined_df.index >= "2024-01-01"
text_2024 = " ".join(combined_df.loc[mask_2024, "content_clean"].astype(str))

wc_2024 = WordCloud(
    width=1200,
    height=600,
    background_color="white"
).generate(text_2024)

plt.figure(figsize=(14, 7))
plt.imshow(wc_2024, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
mask_2025 = combined_df.index >= "2025-01-01"
text_2025 = " ".join(combined_df.loc[mask_2025, "content_clean"].astype(str))

wc_2025 = WordCloud(
    width=1200,
    height=600,
    background_color="white"
).generate(text_2025)

plt.figure(figsize=(14, 7))
plt.imshow(wc_2025, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
combined_df.to_csv("merged_kaggle_collected_news.csv", index=True, encoding="utf-8-sig")
